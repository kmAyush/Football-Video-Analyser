# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd ./drive/MyDrive/MovieData/Football_Analyser/
# Out:
# /content/drive/MyDrive/MovieData/Football_Analyser

# %%
# !ls
# Out:
# football_sample.mp4  yolov8x.pt

# %%
# !pip install ultralytics -q
# !pip install roboflow -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.8/823.8 kB 10.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 55.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.7/76.7 kB 3.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 7.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 7.0 MB/s eta 0:00:00

# %% [markdown]
# ## Dataset

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="XXXXXXXXXXXX")
project = rf.workspace("roboflow-xxxxx").project("football-players-detection-3zvbc")
version = project.version(1)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to football-players-detection-1 in yolov5pytorch:: 100%|██████████| 1338/1338 [00:11<00:00, 115.78it/s]

# %%
dataset.location
# Out:
# '/content/drive/MyDrive/MovieData/Football_Analyser/football-players-detection-1'

# %%
import shutil
shutil.move("football-players-detection-1/train", "football-players-detection-1/football-players-detection-1/train")
shutil.move("football-players-detection-1/test", "football-players-detection-1/football-players-detection-1/test")
shutil.move("football-players-detection-1/valid", "football-players-detection-1/football-players-detection-1/valid")
# Out:
# 'football-players-detection-1/football-players-detection-1/valid'

# %% [markdown]
# ##Training

# %%
# !yolo task=detect mode=train model=yolov5l.pt data={dataset.location}/data.yaml epochs=100 imgsz=640
# Out:
# PRO TIP 💡 Replace 'model=yolov5l.pt' with new 'model=yolov5lu.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# ...
# 100% 102M/102M [00:00<00:00, 228MB/s]
# Ultralytics YOLOv8.2.63 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
